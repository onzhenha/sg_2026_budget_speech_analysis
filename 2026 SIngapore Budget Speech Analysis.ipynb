# %% [markdown]
# # Set dependencies and functions

# %%
import string
import nltk
from nltk.corpus import stopwords
from nltk import FreqDist
import pandas as pd
from nltk.tokenize import word_tokenize
import numpy as np

from lets_plot import *
LetsPlot.setup_html()
# Out:
#             <div id="oschGi"></div>
#             <script type="text/javascript" data-lets-plot-script="library">
#                 if(!window.letsPlotCallQueue) {
#                     window.letsPlotCallQueue = [];
#                 };
#                 window.letsPlotCall = function(f) {
#                     window.letsPlotCallQueue.push(f);
#                 };
#                 (function() {
#                     var script = document.createElement("script");
#                     script.type = "text/javascript";
#                     script.src = "https://cdn.jsdelivr.net/gh/JetBrains/lets-plot@v4.7.3/js-package/distr/lets-plot.min.js";
#                     script.onload = function() {
#                         window.letsPlotCall = function(f) {f();};
#                         window.letsPlotCallQueue.forEach(function(f) {f();});
#                         window.letsPlotCallQueue = [];
#
#                     };
#                     script.onerror = function(event) {
#                         window.letsPlotCall = function(f) {};    // noop
#                         window.letsPlotCallQueue = [];
#                         var div = document.createElement("div");
#                         div.style.color = 'darkred';
#                         div.textContent = 'Error loading Lets-Plot JS';
#                         document.getElementById("oschGi").appendChild(div);
#                     };
#                     var e = document.getElementById("oschGi");
#                     e.appendChild(script);
#                 })()
#             </script>

# %%
stop_words = set(stopwords.words("english"))
stop_words.update(["also", "'s", "us", "must", "many"])

def clean_our_text_pythonian(text):
    tokens = word_tokenize(text)
    return " ".join(
        [word for word in tokens 
         if word.lower() not in stop_words 
         and not word.isdigit() 
         and word not in string.punctuation]
    )

# %% [markdown]
# # Import data

# %%
Text = open("Lawrence Wong Speech.txt").read()

Text
# Out:
# "Mr. Speaker, I move that parliament approves the financial policy of the government for the financial year 1st\nApril 2026 to 31st March 2027. This is our first budget in this new\nterm of government. It comes as we enter a post SG60 phase in our nation building\njourney. We begin this next phase at a time of profound global change.\nFor nearly eight decades, the world benefited from an international order\nthat supported econ stability and economic cooperation.\nThe system rested in large part on the leadership of the United States. It underwrote global security, champion\nopen markets, and helped form the institutions and rules that enabled shared prosperity across the world,\nincluding here in Asia. That era has now come to an end.\nThe US is reassessing and in some areas undoing key elements of the very system\nit once helped to build. Trade rules that were once promoted are being set aside. Global institutions are\nbeing bypassed and longstanding norms are becoming less reliable.\nThe cumulative effect is a weakening of the multilateral system. Countries everywhere have less confidence that\ncommon rules will protect their interests. As a result, more states are resorting to unilateral action and some\nare becoming emboldened to do so. At the same time, the guard rails that\nonce managed disputes and tensions are eroding. And so, the world is becoming\nmore contested, more fragmented, and ultimately more dangerous.\nAgainst this backdrop, last year there was widespread expectation that the US Liberation Day tariffs would trigger a\nsharp global slowdown. Unfortunately, our worst fears did not materialize. Many firms adjusted\nquickly, frontloading production and imports to get ahead of the tariff measures. Subsequent trade deals\ntogether with shifts in global supply chains helped to reduce the actual impact of the tariffs.\nAs a result, growth in the major economies held up supported in part by\nstrong investment in AI related activities. In short, despite mounting stresses, the\nglobal economy proved more resilient than anticipated and the international system continued to function.\nThis year, however, we may not be so fortunate. Events in just the first month of 2026 have already been of\nexceptional scale and consequence. They have increased geopolitical tensions worldwide. As pressures build and the\nmargin for error narrows, the resilience of the global system will be tested far more severely.\nThere are also clear and growing signs of fragility in the global economy.\nRising public debt in many major economies will strain financial stability and weigh on longerterm growth\nprospects. At the same time, heightened risk-taking in financial markets has\npushed up asset valuations, leaving them vulnerable to abrupt corrupt\ncorrections, and any such adjustment would dampen confidence and spill over into real economic activity.\nThese external developments have a direct bearing on us. Last year, the\nresilience of the global economy combined with our own economic strength resulted in better than expected growth\nof 5%. Strong external demand boosted key industry clusters including\nelectronics and biomedical manufacturing and these gains generated spillover\nacross the broader economy. Some of the positive momentum will\ncontinue into this year, but amidst heightened global uncertainties, we expect a more moderate outlook for 2026.\nGrowth is therefore projected at 2 to 4% with inflation at 1 to 2%.\nDespite these uncertainties, we can move forward with confidence. Confidence\ngrounded in fundamentals. Over the decades, we have systematically strengthened our economic foundations,\ndeepening capabilities, investing in our people, and reshaping our industries as\ntechnologies evolve. We have built a reputation as a reliable and trusted\nhub, stable, secure, and well-governed, qualities that businesses and investors\nhave come to value highly, more so now than before, precisely because the world has become more fractured ...

# %% [markdown]
# # Data Wrangling
# ## Remove stopwords, punctuations, lower text

# %%
cleaned_text =\
(
    clean_our_text_pythonian(Text)
)

cleaned_text
# Out:
# "Mr. Speaker move parliament approves financial policy government financial year 1st April 31st March first budget new term government comes enter post SG60 phase nation building journey begin next phase time profound global change nearly eight decades world benefited international order supported econ stability economic cooperation system rested large part leadership United States underwrote global security champion open markets helped form institutions rules enabled shared prosperity across world including Asia era come end reassessing areas undoing key elements system helped build Trade rules promoted set aside Global institutions bypassed longstanding norms becoming less reliable cumulative effect weakening multilateral system Countries everywhere less confidence common rules protect interests result states resorting unilateral action becoming emboldened time guard rails managed disputes tensions eroding world becoming contested fragmented ultimately dangerous backdrop last year widespread expectation Liberation Day tariffs would trigger sharp global slowdown Unfortunately worst fears materialize firms adjusted quickly frontloading production imports get ahead tariff measures Subsequent trade deals together shifts global supply chains helped reduce actual impact tariffs result growth major economies held supported part strong investment AI related activities short despite mounting stresses global economy proved resilient anticipated international system continued function year however may fortunate Events first month already exceptional scale consequence increased geopolitical tensions worldwide pressures build margin error narrows resilience global system tested far severely clear growing signs fragility global economy Rising public debt major economies strain financial stability weigh longerterm growth prospects time heightened risk-taking financial markets pushed asset valuations leaving vulnerable abrupt corrupt corrections adjustment would dampen confidence spill real economic activity external developments direct bearing Last year resilience global economy combined economic strength resulted better expected growth Strong external demand boosted key industry clusters including electronics biomedical manufacturing gains generated spillover across broader economy positive momentum continue year amidst heightened global uncertainties expect moderate outlook Growth therefore projected inflation Despite uncertainties move forward confidence Confidence grounded fundamentals decades systematically strengthened economic foundations deepening capabilities investing people reshaping industries technologies evolve built reputation reliable trusted hub stable secure well-governed qualities businesses investors come value highly precisely world become fractured uncertain give Singapore important tangible competitive advantage past success alone carry forward profoundly changed world standing still option wait conditions turn favorable fall back strategies designed previous era therefore full agenda term government refresh strategies strengthen social compact Budget first step effort secure future changed world lays groundwork navigate next phase development together one people budget advance refreshed economic strategy harness artificial intelligence strategic advantage build resilient skilled workforce give families support greater assurance protect security sustainability renew strengthen Singapore spirit touch turn Advancing Refreshed Economic Strategy economy well last year businesses continue face cost pressures operating challenges support businesses help stay competitive provide corporate income tax rebate year assessment Every active company employed least one local employee last year receive minimum benefit 1,500 total benefit company capped 30,000 provide short-term relief press restructuring transformation efforts Growth harder changed world aim higher move faster prepared take calculated risk government convened econom ...

# %% [markdown]
# ## Tokenise your text so the machine can process it

# %%
tokens=\
(
    nltk
    .word_tokenize(cleaned_text
                  .lower()
                  )
)

tokens
# Out:
# ['mr.',
#  'speaker',
#  'move',
#  'parliament',
#  'approves',
#  'financial',
#  'policy',
#  'government',
#  'financial',
#  'year',
#  '1st',
#  'april',
#  '31st',
#  'march',
#  'first',
#  'budget',
#  'new',
#  'term',
#  'government',
#  'comes',
#  'enter',
#  'post',
#  'sg60',
#  'phase',
#  'nation',
#  'building',
#  'journey',
#  'begin',
#  'next',
#  'phase',
#  'time',
#  'profound',
#  'global',
#  'change',
#  'nearly',
#  'eight',
#  'decades',
#  'world',
#  'benefited',
#  'international',
#  'order',
#  'supported',
#  'econ',
#  'stability',
#  'economic',
#  'cooperation',
#  'system',
#  'rested',
#  'large',
#  'part',
#  'leadership',
#  'united',
#  'states',
#  'underwrote',
#  'global',
#  'security',
#  'champion',
#  'open',
#  'markets',
#  'helped',
#  'form',
#  'institutions',
#  'rules',
#  'enabled',
#  'shared',
#  'prosperity',
#  'across',
#  'world',
#  'including',
#  'asia',
#  'era',
#  'come',
#  'end',
#  'reassessing',
#  'areas',
#  'undoing',
#  'key',
#  'elements',
#  'system',
#  'helped',
#  'build',
#  'trade',
#  'rules',
#  'promoted',
#  'set',
#  'aside',
#  'global',
#  'institutions',
#  'bypassed',
#  'longstanding',
#  'norms',
#  'becoming',
#  'less',
#  'reliable',
#  'cumulative',
#  'effect',
#  'weakening',
#  'multilateral',
#  'system',
#  'countries',
#  'everywhere',
#  'less',
#  'confidence',
#  'common',
#  'rules',
#  'protect',
#  'interests',
#  'result',
#  'states',
#  'resorting',
#  'unilateral',
#  'action',
#  'becoming',
#  'emboldened',
#  'time',
#  'guard',
#  'rails',
#  'managed',
#  'disputes',
#  'tensions',
#  'eroding',
#  'world',
#  'becoming',
#  'contested',
#  'fragmented',
#  'ultimately',
#  'dangerous',
#  'backdrop',
#  'last',
#  'year',
#  'widespread',
#  'expectation',
#  'liberation',
#  'day',
#  'tariffs',
#  'would',
#  'trigger',
#  'sharp',
#  'global',
#  'slowdown',
#  'unfortunately',
#  'worst',
#  'fears',
#  'materialize',
#  'firms',
#  'adjusted',
#  'quickly',
#  'frontloading',
#  'production',
#  'imports',
#  'get',
#  'ahead',
#  'tariff',
#  'measures',
#  'subsequent',
#  'trade',
#  'deals',
#  'together',
#  'shifts',
#  'global',
#  'supply',
#  'chains',
#  'helped',
#  'reduce',
#  'actual',
#  'impact',
#  'tariffs',
#  'result',
#  'growth',
#  'major',
#  'economies',
#  'held',
#  'supported',
#  'part',
#  'strong',
#  'investment',
#  'ai',
#  'related',
#  'activities',
#  'short',
#  'despite',
#  'mounting',
#  'stresses',
#  'global',
#  'economy',
#  'proved',
#  'resilient',
#  'anticipated',
#  'international',
#  'system',
#  'continued',
#  'function',
#  'year',
#  'however',
#  'may',
#  'fortunate',
#  'events',
#  'first',
#  'month',
#  'already',
#  'exceptional',
#  'scale',
#  'consequence',
#  'increased',
#  'geopolitical',
#  'tensions',
#  'worldwide',
#  'pressures',
#  'build',
#  'margin',
#  'error',
#  'narrows',
#  'resilience',
#  'global',
#  'system',
#  'tested',
#  'far',
#  'severely',
#  'clear',
#  'growing',
#  'signs',
#  'fragility',
#  'global',
#  'economy',
#  'rising',
#  'public',
#  'debt',
#  'major',
#  'economies',
#  'strain',
#  'financial',
#  'stability',
#  'weigh',
#  'longerterm',
#  'growth',
#  'prospects',
#  'time',
#  'heightened',
#  'risk-taking',
#  'financial',
#  'markets',
#  'pushed',
#  'asset',
#  'valuations',
#  'leaving',
#  'vulnerable',
#  'abrupt',
#  'corrupt',
#  'corrections',
#  'adjustment',
#  'would',
#  'dampen',
#  'confidence',
#  'spill',
#  'real',
#  'economic',
#  'activity',
#  'external',
#  'developments',
#  'direct',
#  'bearing',
#  'last',
#  'year',
#  'resilience',
#  'global',
#  'economy',
#  'combined',
#  'economic',
#  'strength',
#  'resulted',
#  'better',
#  'expected',
#  'growth',
#  'strong',
#  'external',
#  'demand',
#  'boosted',
#  'key',
#  'industry',
#  'clusters',
#  'including',
#  'electronics',
#  'biomedical',
#  'manufacturing',
#  'gains',
#  'generated',
#  'spillover',
#  'across',
#  'broader',
#  'economy',
#  'positive',
#  'momentum',
#  'continue',
#  'year',
#  'amidst',
#  'heightened',
#  'global',
#  'uncertainties',
#  'expect',
#  'moderate',
#  'outlook',
#  'growth',
#  'therefore',
#  'projected',
#  'inflation',
#  'despite',
#  'uncertainties',
#  'move',
#  'forward',
#  'confidence',
#  'confidence',
#  'grounded',
#  'fundamentals',
#  'decades',
#  'systematically',
#  'strengthened',
#  'economic',
#  'foundations',
#  'deepening',
#  'capabilities',
#  'investing',
#  'people',
#  'reshaping',
#  'industries',
#  'technologies',
#  'evolve',
#  'built',
#  'reputation',
#  'reliable',
#  'trusted',
#  'hub',
#  'stable',
#  'secure',
#  'well-governed',
#  'qualities',
#  'businesses',
#  'investors',
#  'come',
#  'value',
#  'highly',
#  'precisely',
#  'world',
#  'become',
#  'fractured',
#  'uncertain',
#  'give',
#  'singapore',
#  'important',
#  'tangible',
#  'competitive',
#  'advantage',
#  'past',
#  'success',
#  'alone',
#  'carry',
#  'forward',
#  'profoundly',
#  'changed',
#  'world',
#  'standing',
#  'still',
#  'option',
#  'wait',
#  'conditions',
#  'turn',
#  'favorable',
#  'fall',
#  'back',
#  'strategies',
#  'designed',
#  'previous',
#  'era',
#  'therefore',
#  'full',
#  'agenda',
#  'term',
#  'government',
#  'refresh',
#  'strategies',
#  'strengthen',
#  'social',
#  'compact',
#  'budget',
#  'first',
#  'step',
#  'effort',
#  'secure',
#  'future',
#  'changed',
#  'world',
#  'lays',
#  'groundwork',
#  'navigate',
#  'next',
#  'phase',
#  'development',
#  'together',
#  'one',
#  'people',
#  'budget',
#  'advance',
#  'refreshed',
#  'economic',
#  'strategy',
#  'harness',
#  'artificial',
#  'intelligence',
#  'strategic',
#  'advantage',
#  'build',
#  'resilient',
#  'skilled',
#  'workforce',
#  'give',
#  'families',
#  'support',
#  'greater',
#  'assurance',
#  'protect',
#  'security',
#  'sustainability',
#  'renew',
#  'strengthen',
#  'singapore',
#  'spirit',
#  'touch',
#  'turn',
#  'advancing',
#  'refreshed',
#  'economic',
#  'strategy',
#  'economy',
#  'well',
#  'last',
#  'year',
#  'businesses',
#  'continue',
#  'face',
#  'cost',
#  'pressures',
#  'operating',
#  'challenges',
#  'support',
#  'businesses',
#  'help',
#  'stay',
#  'competitive',
#  'provide',
#  'corporate',
#  'income',
#  'tax',
#  'rebate',
#  'year',
#  'assessment',
#  'every',
#  'active',
#  'company',
#  'employed',
#  'least',
#  'one',
#  'local',
#  'employee',
#  'last',
#  'year',
#  'receive',
#  'minimum',
#  'benefit',
#  '1,500',
#  'total',
#  'benefit',
#  'company',
#  'capped',
#  '30,000',
#  'provide',
#  'short-term',
#  'relief',
#  'press',
#  'restructuring',
#  'transformation',
#  'efforts',
#  'growth',
#  'harder',
#  'changed',
#  'world',
#  'aim',
#  'higher',
#  'move',
#  'faster',
#  'prepared',
#  'take',
#  'calculated',
#  'risk',
#  'government',
#  'convened',
#  'economic',
#  'strategy',
#  'review',
#  'esr',
#  'committee',
#  'shared',
#  'midterm',
#  'update',
#  'last',
#  'month',
#  'move',
#  'decisively',
#  'act',
#  'recommendations',
#  'ambition',
#  'secure',
#  'growth',
#  'higher',
#  'end',
#  'range',
#  'next',
#  'decade',
#  'growth',
#  'enough',
#  'growth',
#  'translate',
#  'good',
#  'jobs',
#  'rising',
#  'incomes',
#  'singaporeans',
#  'let',
#  'share',
#  'achieve',
#  'first',
#  'adapt',
#  'connect',
#  'differently',
#  'changed',
#  'global',
#  'environment',
#  'countries',
#  'turning',
#  'inward',
#  'seeking',
#  'reduce',
#  'external',
#  'dependence',
#  'singapore',
#  'option',
#  'prosper',
#  'still',
#  'need',
#  'connected',
#  'world',
#  'trading',
#  'others',
#  'integrating',
#  'global',
#  'flows',
#  'importantly',
#  'globalization',
#  'ended',
#  'country',
#  'succeed',
#  'major',
#  'products',
#  'still',
#  'depend',
#  'global',
#  'division',
#  'labor',
#  'combining',
#  'expertise',
#  'materials',
#  'countries',
#  'access',
#  'global',
#  'markets',
#  'achieve',
#  'scale',
#  'fundamental',
#  'reality',
#  'changed',
#  'changed',
#  'globalization',
#  'knew',
#  'economic',
#  'flows',
#  'becoming',
#  'selective',
#  'partnerships',
#  'strategic',
#  'resilience',
#  'matters',
#  'much',
#  'efficiency',
#  'singapore',
#  'adjust',
#  'new',
#  'patterns',
#  'staying',
#  'open',
#  'connecting',
#  'smarter',
#  'diversified',
#  'resilient',
#  'ways',
#  'forging',
#  'new',
#  'forms',
#  'cooperation',
#  'partners',
#  'share',
#  'commitment',
#  'last',
#  'year',
#  'launched',
#  'future',
#  'investment',
#  'trade',
#  'partnership',
#  'bringing',
#  'together',
#  'like-minded',
#  'partners',
#  'cooperate',
#  'areas',
#  'like',
#  'technology',
#  'trade',
#  'facilitation',
#  'supply',
#  'chain',
#  'resilience',
#  'month',
#  'eu',
#  'singapore',
#  'digital',
#  'trade',
#  'agreement',
#  'entered',
#  'force',
#  'landmark',
#  'agreement',
#  'robust',
#  'rules',
#  'digital',
#  'trade',
#  'later',
#  'year',
#  'sign',
#  'firstofits-kind',
#  'agreement',
#  'trade',
#  'essential',
#  'supplies',
#  'new',
#  'zealand',
#  'ensure',
#  'continuity',
#  'critical',
#  'trade',
#  'flows',
#  'two',
#  'countries',
#  'times',
#  'crisis',
#  'step',
#  'engagement',
#  'fast',
#  'growing',
#  'markets',
#  'including',
#  'latin',
#  'america',
#  'africa',
#  'middle',
#  'east',
#  'establish',
#  'new',
#  'embassies',
#  'strengthen',
#  'diplomatic',
#  'economic',
#  'presence',
#  'ground',
#  'take',
#  'better',
#  'advantage',
#  'emerging',
#  'opportunities',
#  'regions',
#  'closer',
#  'home',
#  'working',
#  'neighbors',
#  'deepen',
#  'regional',
#  'integration',
#  'includes',
#  'cooperating',
#  'projects',
#  'like',
#  'johor',
#  'singapore',
#  'special',
#  'economic',
#  'zone',
#  'batam',
#  'bintan',
#  'karimoon',
#  'free',
#  'trade',
#  'zones',
#  'indonesia',
#  'short',
#  'redouble',
#  'efforts',
#  'diversify',
#  'globally',
#  'integrate',
#  'regionally',
#  'connectivity',
#  'alone',
#  'enough',
#  'translate',
#  'rail',
#  'opportunities',
#  'businesses',
#  'capture',
#  'seize',
#  'companies',
#  'singapore',
#  'companies',
#  'already',
#  'one',
#  'example',
#  'rotary',
#  'engineering',
#  'started',
#  'offering',
#  'electrical',
#  'installation',
#  'services',
#  'oil',
#  'refineries',
#  'prochemical',
#  'plants',
#  'singapore',
#  'confine',
#  'domestic',
#  'market',
#  'time',
#  'built',
#  'leading',
#  'presence',
#  'southeast',
#  'asia',
#  'delivering',
#  'energy',
#  'infrastructure',
#  'services',
#  'venturing',
#  'field',
#  'deepening',
#  'presence',
#  'middle',
#  'east',
#  'business',
#  'overseas',
#  'easy',
#  'especially',
#  'smaller',
#  'firms',
#  'companies',
#  'face',
#  'unfamiliar',
#  'regulations',
#  'different',
#  'business',
#  'practices',
#  'intense',
#  'local',
#  'competition',
#  'support',
#  'companies',
#  'venture',
#  'abroad',
#  'enhance',
#  'support',
#  'levels',
#  'grant',
#  'schemes',
#  'support',
#  'companies',
#  'internationalize',
#  'small',
#  'medium',
#  'enterprises',
#  'ormemes',
#  'nonmemes',
#  'enhance',
#  'market',
#  'readiness',
#  'assistance',
#  'grant',
#  'support',
#  'companies',
#  'access',
#  'new',
#  'markets',
#  'deepen',
#  'activities',
#  'existing',
#  'overseas',
#  'markets',
#  'well',
#  'double',
#  'tax',
#  'deduction',
#  'internationalization',
#  'scheme',
#  'companies',
#  'automatically',
#  'enjoy',
#  'tax',
#  'deduction',
#  'selected',
#  'qualifying',
#  'activities',
#  'capped',
#  '150,000',
#  'allow',
#  'qualifying',
#  'activities',
#  'eligible',
#  'automatic',
#  'tax',
#  'deduction',
#  'claims',
#  'raise',
#  'cap',
#  '400,000',
#  'enhance',
#  'enterprise',
#  'financing',
#  'scheme',
#  'increasing',
#  'maximum',
#  'loan',
#  'quantum',
#  'trade',
#  'fixed',
#  'asset',
#  'loans',
#  'give',
#  'companies',
#  'flexibility',
#  'cater',
#  'different',
#  'financing',
#  'needs',
#  'provide',
#  'support',
#  'companies',
#  'pursuing',
#  'significant',
#  'overseas',
#  'ventures',
#  'require',
#  'higher',
#  'capital',
#  'outlay',
#  'minister',
#  'trade',
#  'industry',
#  'share',
#  'changes',
#  'committee',
#  'supply',
#  'second',
#  'build',
#  'build',
#  'leadership',
#  'key',
#  'growth',
#  'clusters',
#  'means',
#  'anchoring',
#  'critical',
#  'segments',
#  'global',
#  'value',
#  'chains',
#  'singapore',
#  'especially',
#  'activities',
#  'high',
#  'knowledge',
#  'content',
#  'strong',
#  'spillovers',
#  'goal',
#  'host',
#  'activities',
#  'shape',
#  'industries',
#  'develop',
#  'create',
#  'value',
#  'already',
#  'areas',
#  'like',
#  'semiconductors',
#  'key',
#  'frontier',
#  'semiconductors',
#  'advanced',
#  'packaging',
#  'despite',
#  'name',
#  'suggests',
#  'advanced',
#  'packaging',
#  'highly',
#  'complex',
#  'technologically',
#  'demanding',
#  'traditionally',
#  'faster',
#  'chips',
#  'built',
#  'packing',
#  'transistors',
#  'onto',
#  'single',
#  'chip',
#  'becoming',
#  'costly',
#  'approaching',
#  'physical',
#  'limits',
#  'result',
#  'attention',
#  'shifted',
#  'advanced',
#  'packaging',
#  'integrates',
#  'multiple',
#  'chips',
#  'single',
#  'package',
#  'using',
#  'highly',
#  'precise',
#  'manufacturing',
#  'technologies',
#  'delivers',
#  'higher',
#  'better',
#  'performance',
#  'energy',
#  'efficiency',
#  'singapore',
#  'began',
#  'investing',
#  'advanced',
#  'packaging',
#  'r',
#  'two',
#  'decades',
#  'ago',
#  'well',
#  'became',
#  'global',
#  'priority',
#  'investments',
#  'bearing',
#  'fruit',
#  'one',
#  'reason',
#  'major',
#  'semiconductor',
#  'companies',
#  'continue',
#  'invest',
#  'heavily',
#  'singapore',
#  'manufacturing',
#  'r',
#  'innovation',
#  'supply',
#  'chain',
#  'partnerships',
#  'see',
#  'similar',
#  'pattern',
#  'key',
#  'industries',
#  'like',
#  'aerospace',
#  'biomedical',
#  'science',
#  'technology',
#  'critical',
#  ...]

# %% [markdown]
# # Calculate and model frequency and 20 most common words

# %%
# Calculate frequency distribution
fdist = FreqDist(tokens)

# Find the 20 most common words
top_20_words=\
(
    pd
    .DataFrame((fdist.most_common(20)))
)
top_20_words_renamed =\
(
    top_20_words.rename(columns = {0: "words", 1: "volume"})
)

# %%
top_20_words_renamed
# Out:
#            words  volume
# 0      singapore      84
# 1        support      64
# 2             ai      54
# 3   singaporeans      39
# 4           year      37
# 5       continue      34
# 6            new      33
# 7      companies      31
# 8           help      30
# 9       families      29
# 10           one      28
# 11       workers      28
# 12        global      26
# 13         build      26
# 14    strengthen      26
# 15       provide      26
# 16        skills      26
# 17    government      25
# 18          work      24
# 19        growth      23

# %%
top_20_words_renamed.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   words   20 non-null     object
#  1   volume  20 non-null     int64
# dtypes: int64(1), object(1)
# memory usage: 452.0+ bytes

# %%
top_20_words_renamed.columns
# Out:
# Index(['words', 'volume'], dtype='object')

# %% [markdown]
# # Data visualisation (top 20 keywords used during speech)

# %%
top_20_keywords_SG_budget_2026=\
(
    ggplot(top_20_words_renamed,
           aes(x = "words",
               y = "volume")
          )
    + geom_bar(stat = "identity")
    # + coord_flip()
    + labs(title = "Frequency of words in Prime Minister Lawrence Wong 2026 Budget Speech",
           subtitle = "Top 3 words are 'Singapore', 'Support' and 'AI'",
           caption = "Source: Youtube Transcript")
    + geom_segment(x = 2, xend = 2,
                   y = 65, yend = 60, 
                   arrow = arrow(length = 10, 
                                 type='closed'), 
                   color = "red"
                  )
    + geom_segment(x = 1, xend = 1,
                   y = 75, yend = 70, 
                   arrow = arrow(length = 10, 
                                 type='closed'), 
                   color = "red"
                  )
    + geom_segment(x = 0, xend = 0,
                   y = 95, yend = 90, 
                   arrow = arrow(length = 10, 
                                 type='closed'), 
                   color = "red"
                  )
    + theme_classic()
    + ggsize(1700,800)
)

# %%
top_20_keywords_SG_budget_2026
# Out:
#    <div id="IffphO"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("IffphO");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "words":["singapore","support","ai","singaporeans","year","continue","new","companies","help","families","one","workers","global","build","strengthen","provide","skills","government","work","growth"],
# "volume":[84.0,64.0,54.0,39.0,37.0,34.0,33.0,31.0,30.0,29.0,28.0,28.0,26.0,26.0,26.0,26.0,26.0,25.0,24.0,23.0]
# },
# "mapping":{
# "x":"words",
# "y":"volume"
# },
# "data_meta":{
# "series_annotations":[{
# "type":"str",
# "column":"words"
# },{
# "type":"int",
# "column":"volume"
# }]
# },
# "ggtitle":{
# "text":"Frequency of words in Prime Minister Lawrence Wong 2026 Budget Speech",
# "subtitle":"Top 3 words are 'Singapore', 'Support' and 'AI'"
# },
# "caption":{
# "text":"Source: Youtube Transcript"
# },
# "theme":{
# "name":"classic"
# },
# "ggsize":{
# "width":1700.0,
# "height":800.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"bar",
# "stat":"identity",
# "mapping":{
# },
# "data_meta":{
# },
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":10.0,
# "type":"closed"
# },
# "x":2.0,
# "xend":2.0,
# "y":65.0,
# "yend":60.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":10.0,
# "type":"closed"
# },
# "x":1.0,
# "xend":1.0,
# "y":75.0,
# "yend":70.0,
# "color":"red",
# "data":{
# }
# },{
# "geom":"segment",
# "mapping":{
# },
# "data_meta":{
# },
# "arrow":{
# "name":"arrow",
# "length":10.0,
# "type":"closed"
# },
# "x":0.0,
# "xend":0.0,
# "y":95.0,
# "yend":90.0,
# "color":"red",
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"22"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# # Model the top 3 most used keywords

# %%
from nltk.draw.dispersion import dispersion_plot

# %%
# Based on the top 3 words usage, let's see dispersion too
finance_words_of_interest = ["singapore", "support", "ai"]

# %%
rows = []

rows =\
    [
        {"index": idx,
         "word": tok}
        for idx, tok
        in enumerate(tokens)
        if tok in finance_words_of_interest
    ]

df_wong_2026 =\
(
    pd
    .DataFrame(rows)
)

# %%
df_wong_2026
# Out:
#      index       word
# 0      176         ai
# 1      346  singapore
# 2      415    support
# 3      423  singapore
# 4      442    support
# ..     ...        ...
# 197   6278  singapore
# 198   6420  singapore
# 199   6432  singapore
# 200   6480  singapore
# 201   6486    support
#
# [202 rows x 2 columns]

# %% [markdown]
# # Using <mark>dispersion plot</mark> to find out the top 3 keywords frequency and timeseries. Time elapsed between his usage of those target words.

# %%
dispersion_plot_for_wong_2026 =\
(
    ggplot(df_wong_2026)
    + geom_point(aes(x = "index",
                     y = "word",
                     color = "word",
                     shape = "word"),
                 size = 3
                )
    + labs(title = "Prime Minister Lawrence Wong 2026 Budget Speech",
           subtitle = "PM was basically rapping about AI at one point. Crazy.",
           x = "Token Index (Look at the Intervals)",
           y = "Budget Speech Words of Interest")
    + ggsize(1700,800)
)

# %%
dispersion_plot_for_wong_2026
# Out:
#    <div id="1RvAV4"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("1RvAV4");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "index":[176.0,346.0,415.0,423.0,442.0,542.0,591.0,631.0,699.0,727.0,743.0,779.0,784.0,788.0,801.0,858.0,889.0,958.0,982.0,1006.0,1052.0,1119.0,1135.0,1192.0,1216.0,1262.0,1285.0,1343.0,1353.0,1405.0,1466.0,1482.0,1525.0,1562.0,1577.0,1608.0,1624.0,1638.0,1648.0,1651.0,1667.0,1670.0,1691.0,1701.0,1705.0,1716.0,1730.0,1740.0,1746.0,1765.0,1777.0,1800.0,1810.0,1817.0,1834.0,1860.0,1867.0,1868.0,1870.0,1880.0,1884.0,1907.0,1915.0,1922.0,1924.0,1928.0,1932.0,1950.0,1955.0,1978.0,1991.0,2005.0,2038.0,2039.0,2042.0,2060.0,2064.0,2080.0,2089.0,2102.0,2109.0,2115.0,2126.0,2133.0,2136.0,2166.0,2171.0,2196.0,2230.0,2243.0,2259.0,2272.0,2296.0,2320.0,2326.0,2328.0,2352.0,2356.0,2371.0,2387.0,2393.0,2397.0,2421.0,2443.0,2460.0,2467.0,2489.0,2502.0,2578.0,2608.0,2648.0,2662.0,2700.0,2706.0,2709.0,2727.0,2756.0,2832.0,2840.0,2847.0,2885.0,2897.0,2899.0,2922.0,2932.0,2960.0,2980.0,3028.0,3045.0,3086.0,3129.0,3305.0,3337.0,3346.0,3350.0,3356.0,3381.0,3408.0,3422.0,3432.0,3454.0,3481.0,3549.0,3601.0,3617.0,3670.0,3674.0,3701.0,3807.0,3837.0,3869.0,3889.0,3926.0,3960.0,3998.0,4205.0,4276.0,4343.0,4363.0,4467.0,4487.0,4544.0,4586.0,4751.0,4765.0,4822.0,4891.0,4904.0,4935.0,4943.0,4984.0,5081.0,5125.0,5138.0,5178.0,5180.0,5220.0,5296.0,5310.0,5414.0,5473.0,5506.0,5576.0,5599.0,5654.0,5699.0,5738.0,5750.0,5752.0,5780.0,6010.0,6038.0,6141.0,6182.0,6199.0,6217.0,6234.0,6278.0,6420.0,6432.0,6480.0,6486.0],
# "word":["ai","singapore","support","singapore","support","singapore","singapore","singapore","singapore","singapore","singapore","support","support","support","support","support","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","ai","ai","ai","singapore","ai","ai","singapore","ai","singapore","singapore","ai","singapore","ai","ai","ai","ai","ai","singapore","ai","singapore","ai","ai","ai","singapore","ai","ai","ai","ai","singapore","ai","ai","support","ai","support","support","ai","ai","support","ai","singapore","support","ai","support","ai","ai","ai","ai","ai","ai","ai","support","ai","ai","support","ai","singapore","ai","ai","ai","ai","support","ai","ai","ai","ai","ai","ai","support","ai","ai","ai","ai","ai","singapore","ai","singapore","support","support","support","support","support","support","support","singapore","support","singapore","singapore","support","singapore","singapore","support","support","support","support","singapore","support","support","support","singapore","support","support","singapore","support","support","support","support","support","singapore","support","support","support","support","support","support","support","support","support","support","support","support","support","support","support","support","support","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","support","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","support","support","support","singapore","support","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","support","singapore","singapore","singapore","singapore","singapore","singapore","singapore","singapore","support"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"index"
# },{
# "type":"str",
# "column":"word"
# }]
# },
# "ggtitle":{
# "text":"Prime Minister Lawrence Wong 2026 Budget Speech",
# "subtitle":"PM was basically rapping about AI at one point. Crazy."
# },
# "guides":{
# "x":{
# "title":"Token Index (Look at the Intervals)"
# },
# "y":{
# "title":"Budget Speech Words of Interest"
# }
# },
# "ggsize":{
# "width":1700.0,
# "height":800.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"index",
# "y":"word",
# "color":"word",
# "shape":"word"
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"23"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>

# %% [markdown]
# # Model the keywords on business and family topics

# %%
words_of_interest = ["companies", "workers", "families"]

# %%
rows = []

rows =\
    [
        {"index": idx,
         "word": tok}
        for idx, tok
        in enumerate(tokens)
        if tok in words_of_interest
    ]

df_workervsfamily_2026 =\
(
    pd
    .DataFrame(rows)
)

# %% [markdown]
# # Using <mark>dispersion plot</mark> to find out the business topic vs family topic frequency and timeseries. Time elapsed between his usage of those target words.

# %%
dispersion_plot_for_busiess_vs_families_2026 =\
(
    ggplot(df_workervsfamily_2026)
    + geom_point(aes(x = "index",
                     y = "word",
                     color = "word",
                     shape = "word"),
                 size = 3
                )
    + labs(title = "Business vs Family Support",
           subtitle = "From this data it seems there is more focus on supporting the Singapore labour market compared to families",
           x = "Token Index (Look at the Intervals)",
           y = "Budget Speech Words of Interest")
    + ggsize(1700,800)
)

# %%
dispersion_plot_for_busiess_vs_families_2026
# Out:
#    <div id="vjawID"></div>
#    <script type="text/javascript" data-lets-plot-script="plot">
#
#    (function() {
#    // ----------
#
#    const forceImmediateRender = false;
#    const responsive = false;
#
#    let sizing = {
#        width_mode: "MIN",
#        height_mode: "SCALED",
#        width: null,
#        height: null
#    };
#
#    const preferredWidth = document.body.dataset.letsPlotPreferredWidth;
#    if (preferredWidth !== undefined) {
#        sizing = {
#            width_mode: 'FIXED',
#            height_mode: 'SCALED',
#            width: parseFloat(preferredWidth)
#        };
#    }
#
#    const containerDiv = document.getElementById("vjawID");
#    let fig = null;
#
#    function renderPlot() {
#        if (fig === null) {
#            const plotSpec = {
# "data":{
# "index":[414.0,726.0,728.0,769.0,780.0,789.0,802.0,817.0,851.0,859.0,978.0,1128.0,1145.0,1320.0,1444.0,1477.0,1505.0,1512.0,1537.0,1542.0,1606.0,1708.0,1832.0,1874.0,1895.0,1899.0,1908.0,1940.0,1999.0,2135.0,2151.0,2163.0,2173.0,2180.0,2211.0,2270.0,2321.0,2517.0,2611.0,2627.0,2668.0,2710.0,2724.0,2918.0,2991.0,3085.0,3134.0,3147.0,3153.0,3272.0,3336.0,3341.0,3358.0,3375.0,3380.0,3433.0,3471.0,3499.0,3510.0,3527.0,3536.0,3562.0,3577.0,3586.0,3602.0,3633.0,3652.0,3702.0,3708.0,3716.0,3740.0,3755.0,3779.0,3826.0,3843.0,4011.0,4014.0,4353.0,4662.0,4678.0,4689.0,5447.0,5560.0,5586.0,6102.0,6339.0,6414.0,6429.0],
# "word":["families","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","companies","workers","companies","companies","companies","workers","companies","companies","companies","companies","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","workers","companies","workers","families","families","families","families","families","families","families","families","families","families","families","families","families","families","families","families","families","families","workers","families","families","families","families","families","families","workers","workers","families","companies","companies","companies","companies","families","workers","families","families","workers","workers"]
# },
# "mapping":{
# },
# "data_meta":{
# "series_annotations":[{
# "type":"int",
# "column":"index"
# },{
# "type":"str",
# "column":"word"
# }]
# },
# "ggtitle":{
# "text":"Business vs Family Support",
# "subtitle":"From this data it seems there is more focus on supporting the Singapore labour market compared to families"
# },
# "guides":{
# "x":{
# "title":"Token Index (Look at the Intervals)"
# },
# "y":{
# "title":"Budget Speech Words of Interest"
# }
# },
# "ggsize":{
# "width":1700.0,
# "height":800.0
# },
# "kind":"plot",
# "scales":[],
# "layers":[{
# "geom":"point",
# "mapping":{
# "x":"index",
# "y":"word",
# "color":"word",
# "shape":"word"
# },
# "data_meta":{
# },
# "size":3.0,
# "data":{
# }
# }],
# "metainfo_list":[],
# "spec_id":"24"
# };
#            window.letsPlotCall(function() { fig = LetsPlot.buildPlotFromProcessedSpecs(plotSpec, containerDiv, sizing); });
#        } else {
#            fig.updateView({});
#        }
#    }
#
#    const renderImmediately =
#        forceImmediateRender || (
#            sizing.width_mode === 'FIXED' &&
#            (sizing.height_mode === 'FIXED' || sizing.height_mode === 'SCALED')
#        );
#
#    if (renderImmediately) {
#        renderPlot();
#    }
#
#    if (!renderImmediately || responsive) {
#        // Set up observer for initial sizing or continuous monitoring
#        var observer = new ResizeObserver(function(entries) {
#            for (let entry of entries) {
#                if (entry.contentBoxSize &&
#                    entry.contentBoxSize[0].inlineSize > 0) {
#                    if (!responsive && observer) {
#                        observer.disconnect();
#                        observer = null;
#                    }
#                    renderPlot();
#                    if (!responsive) {
#                        break;
#                    }
#                }
#            }
#        });
#
#        observer.observe(containerDiv);
#    }
#
#    // ----------
#    })();
#
#    </script>
